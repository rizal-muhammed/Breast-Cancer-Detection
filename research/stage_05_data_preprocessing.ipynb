# %%
import pandas as pd
from pathlib import Path
import os

# %%
os.getcwd()
# Out:
# '/Users/admin/Documents/Projects/Breast-Cancer-Detection/research'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/Users/admin/Documents/Projects/Breast-Cancer-Detection'

# %%
input_dir = Path("artifacts/training_file_from_db")

# %%
def load_breast_cancer_wisconsin_data(breast_cancer_wisconsin_path=input_dir):
    csv_path = os.path.join(breast_cancer_wisconsin_path, "inputfile.csv")
    return pd.read_csv(csv_path, index_col='index_column')

# %%
bcw = load_breast_cancer_wisconsin_data()
bcw.head()
# Out:
#                     area1      area2        area3  compactness1  compactness2  \
# index_column
# 23            1404.000000  93.989998  2615.000000       0.10220       0.01259
# 114            230.899994   8.966000   284.399994       0.08201       0.02213
# 53            1033.000000  98.809998  1321.000000       0.14850       0.02961
# 110            290.200012  22.870001   367.000000       0.08404       0.02932
# 91             728.200012  29.440001   830.900024       0.10360       0.02444
#
#               compactness3  concave_points1  concave_points2  concave_points3  \
# index_column
# 23                  0.2600          0.08632         0.010380          0.20090
# 114                 0.2364          0.01924         0.010400          0.10500
# 53                  0.2297          0.10600         0.009222          0.13250
# 110                 0.1765          0.01778         0.010230          0.05334
# 91                  0.1997          0.07483         0.017630          0.14760
#
# ...

# %%
bcw = bcw.reset_index(drop=True)
bcw.head()
# Out:
#          area1      area2        area3  compactness1  compactness2  \
# 0  1404.000000  93.989998  2615.000000       0.10220       0.01259
# 1   230.899994   8.966000   284.399994       0.08201       0.02213
# 2  1033.000000  98.809998  1321.000000       0.14850       0.02961
# 3   290.200012  22.870001   367.000000       0.08404       0.02932
# 4   728.200012  29.440001   830.900024       0.10360       0.02444
#
#    compactness3  concave_points1  concave_points2  concave_points3  \
# 0        0.2600          0.08632         0.010380          0.20090
# 1        0.2364          0.01924         0.010400          0.10500
# 2        0.2297          0.10600         0.009222          0.13250
# 3        0.1765          0.01778         0.010230          0.05334
# 4        0.1997          0.07483         0.017630          0.14760
#
#    concavity1  ...  radius3  smoothness1 smoothness2  smoothness3  symmetry1  \
# 0     0.10970  ...   29.170      0.09428    0.004728       0.1401     0.1769
# ...

# %%
bcw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   area1               569 non-null    float64
#  1   area2               569 non-null    float64
#  2   area3               569 non-null    float64
#  3   compactness1        569 non-null    float64
#  4   compactness2        569 non-null    float64
#  5   compactness3        569 non-null    float64
#  6   concave_points1     569 non-null    float64
#  7   concave_points2     569 non-null    float64
#  8   concave_points3     569 non-null    float64
#  9   concavity1          569 non-null    float64
#  10  concavity2          569 non-null    float64
#  11  concavity3          569 non-null    float64
#  12  diagnosis           569 non-null    object
#  13  fractal_dimension1  569 non-null    float64
#  14  fractal_dimension2  569 non-null    float64
# ...

# %%
bcw["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
bcw.describe()
# Out:
#              area1       area2        area3  compactness1  compactness2  \
# count   569.000000  569.000000   569.000000    569.000000    569.000000
# mean    654.889104   40.337079   880.583129      0.104341      0.025478
# std     351.914129   45.491005   569.356992      0.052813      0.017908
# min     143.500000    6.802000   185.199997      0.019380      0.002252
# 25%     420.299988   17.850000   515.299988      0.064920      0.013080
# 50%     551.099976   24.530001   686.500000      0.092630      0.020450
# 75%     782.700012   45.189999  1084.000000      0.130400      0.032450
# max    2501.000000  542.200012  4254.000000      0.345400      0.135400
#
#        compactness3  concave_points1  concave_points2  concave_points3  \
# count    569.000000       569.000000       569.000000       569.000000
# mean       0.254265         0.048919         0.011796         0.114606
# std        0.157336         0.038803         0.006170         0.065732
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Replace 'target_feature' with the actual name of your target feature
target_feature = 'target_feature'

# Sample DataFrame creation
data = {'feature1': [1, 2, 3, 4, 5],
        'feature2': [5, 4, 3, 2, 1],
        'target_feature': [0, 1, 1, 0, 1]}

df = pd.DataFrame(data)

# Calculate the correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix[[target_feature]], annot=True, cmap='coolwarm', fmt=".2f")
plt.title(f'Correlation Matrix with Respect to {target_feature}')
plt.show()

# %%
bcw['diagnosis'] = bcw['diagnosis'].map({'M': 1, 'B': 0})
corr_matrix = bcw.corr()

corr_matrix['diagnosis'].sort_values(ascending=False)
# Out:
# diagnosis             1.000000
# concave_points3       0.793566
# perimeter3            0.782914
# concave_points1       0.776614
# radius3               0.776454
# perimeter1            0.742636
# area3                 0.733825
# radius1               0.730029
# area1                 0.708984
# concavity1            0.696360
# concavity3            0.659610
# compactness1          0.596534
# compactness3          0.590998
# radius2               0.567134
# perimeter2            0.556141
# area2                 0.548236
# texture3              0.456903
# smoothness3           0.421465
# symmetry3             0.416294
# texture1              0.415185
# concave_points2       0.408042
# smoothness1           0.358560
# symmetry1             0.330499
# fractal_dimension3    0.323872
# compactness2          0.292999
# concavity2            0.253730
# fractal_dimension2    0.077972
# symmetry2            -0.006522
# texture2             -0.008303
# fractal_dimension1   -0.012838
# ...

# %%
target_feature = 'diagnosis'
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix[[target_feature]].abs().sort_values(by=target_feature, ascending=False), annot=True, cmap='coolwarm', fmt=".2f")
plt.title(f'Correlation Matrix with Respect to {target_feature}')
plt.show()

# %%
import os
os.chdir("..")
os.getcwd()
# Out:
# '/Users/admin/Documents/Projects/Breast-Cancer-Detection'

# %%
import pandas as pd

label_path = "artifacts/preprocessed_data/test_set/test_set_label.csv"
df = pd.read_csv(label_path)
df.head()
# Out:
#   diagnosis
# 0         B
# 1         M
# 2         B
# 3         M
# 4         B

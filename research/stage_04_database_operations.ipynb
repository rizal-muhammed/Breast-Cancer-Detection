# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/admin/Documents/Projects/Breast-Cancer-Detection/research'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/Users/admin/Documents/Projects/Breast-Cancer-Detection'

# %%
import pandas as pd

path = "artifacts/data_validation_training/training_raw_files_validated/good_raw/breast_cancer_wisconsin.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    concavity1  concave_points1  symmetry1  fractal_dimension1  ...  texture3  \
# 0      0.3001          0.14710     0.2419             0.07871  ...     17.33
# 1      0.0869          0.07017     0.1812             0.05667  ...     23.41
# 2      0.1974          0.12790     0.2069             0.05999  ...     25.53
# 3      0.2414          0.10520     0.2597             0.09744  ...     26.50
# 4      0.1980          0.10430     0.1809             0.05883  ...     16.67
#
#    perimeter3   area3  smoothness3  compactness3  concavity3  concave_points3  \
# ...

# %%
column_data_types = dict(df.dtypes)

# Print or use the dictionary as needed
print(column_data_types)
# Out:
# {'radius1': dtype('float64'), 'texture1': dtype('float64'), 'perimeter1': dtype('float64'), 'area1': dtype('float64'), 'smoothness1': dtype('float64'), 'compactness1': dtype('float64'), 'concavity1': dtype('float64'), 'concave_points1': dtype('float64'), 'symmetry1': dtype('float64'), 'fractal_dimension1': dtype('float64'), 'radius2': dtype('float64'), 'texture2': dtype('float64'), 'perimeter2': dtype('float64'), 'area2': dtype('float64'), 'smoothness2': dtype('float64'), 'compactness2': dtype('float64'), 'concavity2': dtype('float64'), 'concave_points2': dtype('float64'), 'symmetry2': dtype('float64'), 'fractal_dimension2': dtype('float64'), 'radius3': dtype('float64'), 'texture3': dtype('float64'), 'perimeter3': dtype('float64'), 'area3': dtype('float64'), 'smoothness3': dtype('float64'), 'compactness3': dtype('float64'), 'concavity3': dtype('float64'), 'concave_points3': dtype('float64'), 'symmetry3': dtype('float64'), 'fractal_dimension3': dtype('float64'), 'Diagnosis': dtype('O'
# ...

# %%
df.to_csv(os.getcwd()+"test.csv", index=True, index_label='index', header=True)

# %%
df.head()
# Out:
#    index  radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      0    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      1    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      2    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      3    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      4    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    concavity1  concave_points1  symmetry1  ...  texture3  perimeter3   area3  \
# 0      0.3001          0.14710     0.2419  ...     17.33      184.60  2019.0
# 1      0.0869          0.07017     0.1812  ...     23.41      158.80  1956.0
# 2      0.1974          0.12790     0.2069  ...     25.53      152.50  1709.0
# 3      0.2414          0.10520     0.2597  ...     26.50       98.87   567.7
# 4      0.1980          0.10430     0.1809  ...     16.67      152.20  1575.0
#
# ...

# %%
df.tail()
# Out:
#      index  radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 564    564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568    568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  ...  texture3  perimeter3  \
# 564     0.24390          0.13890     0.1726  ...     26.40      166.10
# 565     0.14400          0.09791     0.1752  ...     38.25      155.00
# 566     0.09251          0.05302     0.1590  ...     34.12      126.70
# 567     0.35140          0.15200     0.2397  ...     39.42      184.60
# 568     0.00000          0.00000     0.1587  ...     30.37       59.16
#
#       area3  smoothness3  compactness3  concavity3  concave_points3  \
# ...

# %%
path = "/Users/admin/Documents/Projects/Breast-Cancer-Detectiontest.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    index  Unnamed: 0  radius1  texture1  perimeter1   area1  smoothness1  \
# 0      0           0    17.99     10.38      122.80  1001.0      0.11840
# 1      1           1    20.57     17.77      132.90  1326.0      0.08474
# 2      2           2    19.69     21.25      130.00  1203.0      0.10960
# 3      3           3    11.42     20.38       77.58   386.1      0.14250
# 4      4           4    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  ...  texture3  perimeter3  \
# 0       0.27760      0.3001          0.14710  ...     17.33      184.60
# 1       0.07864      0.0869          0.07017  ...     23.41      158.80
# 2       0.15990      0.1974          0.12790  ...     25.53      152.50
# 3       0.28390      0.2414          0.10520  ...     26.50       98.87
# 4       0.13280      0.1980          0.10430  ...     16.67      152.20
#
#     area3  smoothness3  compactness3  concavity3  concave_points3  symmetry3  \
# ...

# %%
import os
import pandas as pd
import numpy as np
import json

# %%
ASTRA_DB_SECURE_BUNDLE_PATH = "secrets/breast_cancer_detection-token.json"
ASTRA_TOKEN_PATH = "secrets/secure-connect-breast-cancer-detection.zip"

# %%
cloud_config= {
    'secure_connect_bundle': ASTRA_DB_SECURE_BUNDLE_PATH
    }

# %%
with open(ASTRA_TOKEN_PATH) as f:
    secrets = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> with open(ASTRA_TOKEN_PATH) as f:
# ----> <a href='vscode-notebook-cell:/Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a>     secrets = json.load(f)
#
# File /opt/anaconda3/envs/breast_cancer_detection/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
# ...

# %%
with open(ASTRA_TOKEN_PATH, 'r', encoding='latin-1') as f:
    secrets = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> with open(ASTRA_TOKEN_PATH, 'r', encoding='latin-1') as f:
# ----> <a href='vscode-notebook-cell:/Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a>     secrets = json.load(f)
#
# File /opt/anaconda3/envs/breast_cancer_detection/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
# ...

# %%
ASTRA_DB_SECURE_BUNDLE_PATH = "secrets/breast_cancer_detection-token.json"
ASTRA_TOKEN_PATH = "secrets/secure-connect-breast-cancer-detection.zip"

cloud_config= {
                'secure_connect_bundle': ASTRA_DB_SECURE_BUNDLE_PATH
                }

with open(ASTRA_TOKEN_PATH, 'r') as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider, protocol_version = 4)

session = cluster.connect(self.params.ASTRA_DB_KEYSPACE)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb Cell 14 line 9
#       <a href='vscode-notebook-cell:/Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> cloud_config= {
#       <a href='vscode-notebook-cell:/Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>                 'secure_connect_bundle': ASTRA_DB_SECURE_BUNDLE_PATH
#       <a href='vscode-notebook-cell:/Users/admin/Documents/Projects/Breast-Cancer-Detection/research/stage_04_database_operations.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>                 }
# ...

# %%
good_raw = "artifacts/data_validation_training/training_raw_files_validated/good_raw"
file = "breast_cancer_wisconsin.csv"

file_path = os.path.join(good_raw, file)

df = pd.read_csv(file_path)
df = df.fillna(np.nan)
df = df.head(20)

print(df.columns)

# %%
good_raw = "artifacts/data_validation_training/training_raw_files_validated/good_raw"

all_items = os.listdir(good_raw)  # all items in the good_raw directory
# listing only the files in the good_raw directory
only_files = [item for item in all_items if os.path.isfile(os.path.join(good_raw, item)) and item != ".DS_Store"]

if len(only_files) > 0:
    # opening good data files one be one and inserting the data into the given 
    for file in only_files:
        try:
            file_path = os.path.join(good_raw, file)
            df = pd.read_csv(file_path)
            df = df.fillna(np.nan)
            df = df.head(20)

            if(list(self.params.column_names.keys()) == list(df.columns)):
                for index, row in df.iterrows():
                    columns = ", ".join(row.index)
                    values = ", ".join(["%s" for _ in range(len(row))])

                    insert_query = f"INSERT INTO {str(self.config.table_name)} ({columns}) VALUES ({values})"
                    params = tuple(row)

                    self.session.execute(insert_query, params)
            else:
                logger.error(f"Could not insert into the table {str(self.params.table_name)}")
                shutil.move(os.path.join(self.config.good_raw, file), self.config.bad_raw)
                logger.info(f"""Since insertion failed, the file '{str(file)}' moved to 'bad_raw' data successfully""")

        except Exception as e:
            logger.exception( f"Exception occured while inserting data into the table : {str(e)}")
            shutil.move(os.path.join(self.config.good_raw, file), self.config.bad_raw)
            raise e

    logger.info(f"All the 'good_raw' files are inserted successfully into the 'good_raw' table")
else:
    logger.info("Good raw folder is empty. There is nothing to insert.")

# %%
path = "/Users/admin/Documents/Projects/Breast-Cancer-Detection/artifacts/training_file_from_db/inputfile.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    index_column       area1      area2        area3  compactness1  \
# 0             5  477.100006  27.190001   741.599976       0.17000
# 1            10  797.799988  40.509998  1150.000000       0.06669
# 2            16  684.500000  45.400002  1138.000000       0.07200
# 3            13  782.700012  36.580002   876.500000       0.10020
# 4            11  781.000000  54.160000  1299.000000       0.12920
#
#    compactness2  compactness3  concave_points1  concave_points2  \
# 0      0.033450        0.5249          0.08089         0.011370
# 1      0.009269        0.1551          0.03323         0.007591
# 2      0.011620        0.1871          0.05259         0.011090
# 3      0.031260        0.1924          0.05364         0.019920
# 4      0.040610        0.5609          0.06606         0.012820
#
#    concave_points3  ...    radius3  smoothness1  smoothness2 smoothness3  \
# 0          0.17410  ...  15.470000      0.12780     0.007510      0.1791
# ...

# %%
df.columns
# Out:
# Index(['index_column', 'area1', 'area2', 'area3', 'compactness1',
#        'compactness2', 'compactness3', 'concave_points1', 'concave_points2',
#        'concave_points3', 'concavity1', 'concavity2', 'concavity3',
#        'diagnosis', 'fractal_dimension1', 'fractal_dimension2',
#        'fractal_dimension3', 'perimeter1', 'perimeter2', 'perimeter3',
#        'radius1', 'radius2', 'radius3', 'smoothness1', 'smoothness2',
#        'smoothness3', 'symmetry1', 'symmetry2', 'symmetry3', 'texture1',
#        'texture2', 'texture3'],
#       dtype='object')

# %%
df['diagnosis']
# Out:
# 0     M
# 1     M
# 2     M
# 3     M
# 4     M
# 5     M
# 6     B
# 7     M
# 8     M
# 9     M
# 10    M
# 11    M
# 12    M
# 13    M
# 14    M
# 15    M
# 16    M
# 17    M
# 18    M
# 19    M
# Name: diagnosis, dtype: object
